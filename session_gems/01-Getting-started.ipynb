# %% [markdown]
# # Quick start

# %% [markdown]
# ## Loading a model

# %%
from cobra.io import read_sbml_model

# %%
model = read_sbml_model('data/iJO1366.xml.gz')

# %% [markdown]
# ## Simulations

# %%
solution = model.optimize()

# %% [markdown]
# ## Reaction fluxes

# %%
for reaction in model.reactions:
    print(reaction.id, reaction.flux, reaction.name)
# Out:
# DM_4crsol_c 0.00021906891423811674 Sink needed to allow p-Cresol to leave system
# DM_5drib_c 0.0002210336578635639 Sink needed to allow 5'-deoxyribose to leave system
# DM_aacald_c 0.0 Sink needed to allow aminoacetaldehyde to leave system
# DM_amob_c 1.9647436254539616e-06 Sink needed to allow S-Adenosyl-4-methylthio-2-oxobutanoate to leave system
# DM_mththf_c 0.0004401025721016971 Sink needed to allow (2R,4S)-2-methyl-2,3,3,4-tetrahydroxytetrahydrofuran to leave system
# DM_oxam_c 0.0 Sink needed to allow oxamate to leave system
# BIOMASS_Ec_iJO1366_WT_53p95M 0.0 E. coli biomass objective function (iJO1366) - WT - with 53.95 GAM estimate
# BIOMASS_Ec_iJO1366_core_53p95M 0.9823718127269809 E. coli biomass objective function (iJO1366) - core - with 53.95 GAM estimate
# EX_12ppd__R_e 0.0 (R)-Propane-1,2-diol exchange
# EX_12ppd__S_e 0.0 (S)-Propane-1,2-diol exchange
# EX_14glucan_e 0.0 1,4-alpha-D-glucan exchange
# EX_15dap_e 0.0 1,5-Diaminopentane exchange
# EX_23camp_e 0.0 2',3'-Cyclic AMP exchange
# EX_23ccmp_e 0.0 2',3'-Cyclic CMP exchange
# EX_23cgmp_e 0.0 2',3'-Cyclic GMP exchange
# EX_23cump_e 0.0 2',3'-Cyclic UMP exchange
# EX_23dappa_e 0.0 2,3-diaminopropionate exchange
# EX_26dap__M_e 0.0 Meso-2,6-Diaminoheptanedioate exchange
# EX_2ddglcn_e 0.0 2-Dehydro-3-deoxy-D-gluconate exchange
# EX_34dhpac_e 0.0 3,4-Dihydroxyphenylacetaldehyde exchange
# EX_3amp_e 0.0 3'-AMP exchange
# EX_3cmp_e 0.0 3'-cmp exchange
# EX_3gmp_e 0.0 3'-GMP exchange
# EX_3hcinnm_e 0.0 3-hydroxycinnamic acid exchange
# EX_3hpp_e 0.0 3-Hydroxypropanoate exchange
# EX_3hpppn_e 0.0 3-(3-hydroxy-phenyl)propionate exchange
# EX_3ump_e 0.0 3'-UMP exchange
# EX_4abut_e 0.0 4-Aminobutanoate exchange
# EX_4hoxpacd_e 0.0 4-Hydroxyphenylacetaldehyde exchange
# EX_5dglcn_e 0.0 5-Dehydro-D-gluconate exchange
# EX_5mtr_e 0.0 5-Methylthio-D-ribose exchange
# EX_LalaDglu_e 0.0 L-alanine-D-glutamate exchange
# EX_LalaDgluMdap_e 0.0 L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate exchange
# EX_LalaDgluMdapDala_e 0.0 L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine exchange
# EX_LalaLglu_e 0.0 L-alanine-L-glutamate exchange
# EX_ac_e 0.0 Acetate exchange
# EX_acac_e 0.0 Acetoacetate exchange
# EX_acald_e 0.0 Acetaldehyde exchange
# EX_acgal_e 0.0 N-Acetyl-D-galactosamine exchange
# EX_acgal1p_e 0.0 N-Acetyl-D-galactosamine 1-phosphate exchange
# EX_acgam_e 0.0 N-Acetyl-D-glucosamine exchange
# EX_acgam1p_e 0.0 N-Acetyl-D-glucosamine 1-phosphate exchange
# EX_acmana_e 0.0 N-Acetyl-D-mannosamine exchange
# EX_acmum_e 0.0 N-Acetylmuramate exchange
# EX_acnam_e 0.0 N-Acetylneuraminate exchange
# EX_acolipa_e 0.0 4-Amino-4-deoxy-L-arabinose modified core oligosaccharide lipid A exchange
# EX_acser_e 0.0 O-Acetyl-L-serine exchange
# EX_ade_e 0.0 Adenine exchange
# EX_adn_e 0.0 Adenosine exchange
# EX_adocbl_e 0.0 Adenosylcobalamin exchange
# EX_ag_e 0.0 Silver exchange
# EX_agm_e 0.0 Agmatine exchange
# EX_akg_e 0.0 2-Oxoglutarate exchange
# EX_ala_B_e 0.0 Beta-Alanine exchange
# EX_ala__D_e 0.0 D-Alanine exchange
# EX_ala__L_e 0.0 L-Alanine exchange
# EX_alaala_e 0.0 D-Alanyl-D-alanine exchange
# EX_all__D_e 0.0 D-Allose exchange
# EX_alltn_e 0.0 Allantoin exchange
# EX_amp_e 0.0 AMP exchange
# EX_anhgm_e 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid exchange
# EX_arab__L_e 0.0 L-Arabinose exchange
# EX_arbt_e 0.0 Arbutin exchange
# EX_arbtn_e 0.0 Aerobactin minus Fe3 exchange
# EX_arbtn_fe3_e 0.0 Aerobactin exchange
# EX_arg__L_e 0.0 L-Arginine exchange
# EX_ascb__L_e 0.0 L-Ascorbate exchange
# EX_asn__L_e 0.0 L-Asparagine exchange
# EX_aso3_e 0.0 Arsenite exchange
# EX_asp__L_e 0.0 L-Aspartate exchange
# EX_btn_e 0.0 Biotin exchange
# EX_but_e 0.0 Butyrate (n-C4:0) exchange
# EX_butso3_e 0.0 Butanesulfonate exchange
# EX_ca2_e -0.005113245285243936 Calcium exchange
# EX_cbi_e 0.0 Cobinamide exchange
# EX_cbl1_e 0.0 Cob(I)alamin exchange
# EX_cd2_e 0.0 Cadmium exchange
# EX_cgly_e 0.0 Cys-Gly exchange
# EX_chol_e 0.0 Choline exchange
# EX_chtbs_e 0.0 Chitobiose exchange
# EX_cit_e 0.0 Citrate exchange
# EX_cl_e -0.005113245285243936 Chloride exchange
# EX_cm_e 0.0 Chloramphenicol exchange
# EX_cmp_e 0.0 CMP exchange
# EX_co2_e 19.67522263566326 CO2 exchange
# EX_cobalt2_e -2.4559295318174523e-05 Co2+ exchange
# EX_colipa_e 0.0 Core oligosaccharide lipid A exchange
# EX_colipap_e 0.0 Core oligosaccharide lipid A diphosphate exchange
# EX_cpgn_e 0.0 Coprogen exchange
# EX_cpgn_un_e 0.0 Coprogen unloaded (no Fe(III)) exchange
# EX_crn_e 0.0 L-Carnitine exchange
# EX_crn__D_e 0.0 D-carnitine exchange
# EX_csn_e 0.0 Cytosine exchange
# EX_cu_e 0.0 Cu+ exchange
# EX_cu2_e -0.0006965016152234296 Cu2+ exchange
# EX_cyan_e 0.0 Hydrogen cyanide exchange
# EX_cynt_e 0.0 Cyanate exchange
# EX_cys__D_e 0.0 D-Cysteine exchange
# EX_cys__L_e 0.0 L-Cysteine exchange
# EX_cytd_e 0.0 Cytidine exchange
# EX_dad_2_e 0.0 Deoxyadenosine exchange
# EX_damp_e 0.0 DAMP exchange
# EX_dca_e 0.0 Decanoate (n-C10:0) exchange
# EX_dcmp_e 0.0 DCMP exchange
# EX_dcyt_e 0.0 Deoxycytidine exchange
# EX_ddca_e 0.0 Dodecanoate (n-C12:0) exchange
# EX_dgmp_e 0.0 DGMP exchange
# EX_dgsn_e 0.0 Deoxyguanosine exchange
# EX_dha_e 0.0 Dihydroxyacetone exchange
# EX_dimp_e 0.0 DIMP exchange
# EX_din_e 0.0 Deoxyinosine exchange
# EX_dms_e 0.0 Dimethyl sulfide exchange
# EX_dmso_e 0.0 Dimethyl sulfoxide exchange
# EX_dopa_e 0.0 Dopamine exchange
# EX_doxrbcn_e 0.0 Doxorubicin exchange
# EX_dtmp_e 0.0 DTMP exchange
# EX_dump_e 0.0 DUMP exchange
# EX_duri_e 0.0 Deoxyuridine exchange
# EX_eca4colipa_e 0.0 (enterobacterial common antigen)x4 core oligosaccharide lipid A exchange
# EX_enlipa_e 0.0 Phosphoethanolamine KDO(2)-lipid (A) exchange
# EX_enter_e 0.0 Enterochelin exchange
# EX_etha_e 0.0 Ethanolamine exchange
# EX_ethso3_e 0.0 Ethanesulfonate exchange
# EX_etoh_e 0.0 Ethanol exchange
# EX_f6p_e 0.0 D-fructose 6-phosphate exchange
# EX_fald_e 0.0 Formaldehyde exchange
# EX_fe2_e -0.01577787368420804 Fe2+ exchange
# EX_fe3_e 0.0 Fe3+ exchange
# EX_fe3dcit_e 0.0 Fe(III)dicitrate exchange
# EX_fe3dhbzs_e 0.0 Ferric 2,3-dihydroxybenzoylserine exchange
# EX_fe3hox_e 0.0 Fe(III)hydroxamate exchange
# EX_fe3hox_un_e 0.0 Fe(III)hydoxamate, unloaded exchange
# EX_fecrm_e 0.0 Ferrichrome exchange
# EX_fecrm_un_e 0.0 Ferrichrome minus Fe(III) exchange
# EX_feenter_e 0.0 Fe-enterobactin exchange
# EX_feoxam_e 0.0 Ferroxamine exchange
# EX_feoxam_un_e 0.0 Ferroxamine minus Fe(3) exchange
# EX_for_e 0.0 Formate exchange
# EX_fru_e 0.0 D-Fructose exchange
# EX_frulys_e 0.0 Fructoselysine exchange
# EX_fruur_e 0.0 D-Fructuronate exchange
# EX_fuc__L_e 0.0 L-Fucose exchange
# EX_fum_e 0.0 Fumarate exchange
# EX_fusa_e 0.0 Fusidic acid exchange
# EX_g1p_e 0.0 D-Glucose 1-phosphate exchange
# EX_g3pc_e 0.0 Sn-Glycero-3-phosphocholine exchange
# EX_g3pe_e 0.0 Sn-Glycero-3-phosphoethanolamine exchange
# EX_g3pg_e 0.0 Glycerophosphoglycerol exchange
# EX_g3pi_e 0.0 Sn-Glycero-3-phospho-1-inositol exchange
# EX_g3ps_e 0.0 Glycerophosphoserine exchange
# EX_g6p_e 0.0 D-Glucose 6-phosphate exchange
# EX_gal_e 0.0 D-Galactose exchange
# EX_gal_bD_e 0.0 Beta D-Galactose exchange
# EX_gal1p_e 0.0 Alpha-D-Galactose 1-phosphate exchange
# EX_galct__D_e 0.0 D-Galactarate exchange
# EX_galctn__D_e 0.0 D-Galactonate exchange
# EX_galctn__L_e 0.0 L-Galactonate exchange
# EX_galt_e 0.0 Galactitol exchange
# EX_galur_e 0.0 D-Galacturonate exchange
# EX_gam_e 0.0 D-Glucosamine exchange
# EX_gam6p_e 0.0 D-Glucosamine 6-phosphate exchange
# EX_gbbtn_e 0.0 Gamma-butyrobetaine exchange
# EX_gdp_e 0.0 GDP exchange
# EX_glc__D_e -10.0 D-Glucose exchange
# EX_glcn_e 0.0 D-Gluconate exchange
# EX_glcr_e 0.0 D-Glucarate exchange
# EX_glcur_e 0.0 D-Glucuronate exchange
# EX_glcur1p_e 0.0 D-Glucuronate 1-phosphate exchange
# EX_gln__L_e 0.0 L-Glutamine exchange
# EX_glu__L_e 0.0 L-Glutamate exchange
# EX_gly_e 0.0 Glycine exchange
# EX_glyald_e 0.0 D-Glyceraldehyde exchange
# EX_glyb_e 0.0 Glycine betaine exchange
# EX_glyc_e 0.0 Glycerol exchange
# EX_glyc__R_e 0.0 (R)-Glycerate exchange
# EX_glyc2p_e 0.0 Glycerol 2-phosphate exchange
# EX_glyc3p_e 0.0 Glycerol 3-phosphate exchange
# EX_glyclt_e 0.0 Glycolate exchange
# EX_gmp_e 0.0 GMP exchange
# EX_gsn_e 0.0 Guanosine exchange
# EX_gthox_e 0.0 Oxidized glutathione exchange
# EX_gthrd_e 0.0 Reduced glutathione exchange
# EX_gtp_e 0.0 GTP exchange
# EX_gua_e 0.0 Guanine exchange
# EX_h_e 9.026260125596055 H+ exchange
# EX_h2_e 0.0 H2 exchange
# EX_h2o_e 45.619430370034934 H2O exchange
# EX_h2o2_e 0.0 Hydrogen peroxide exchange
# EX_h2s_e 0.0 Hydrogen sulfide exchange
# EX_hacolipa_e 0.0 Hepta-acylated core oligosaccharide lipid A (E. coli) exchange
# EX_halipa_e 0.0 Hepta-acylated KDO(2)-lipid (A) exchange
# EX_hdca_e 0.0 Hexadecanoate (n-C16:0) exchange
# EX_hdcea_e 0.0 Hexadecenoate (n-C16:1) exchange
# EX_hg2_e 0.0 Hg2+ exchange
# EX_his__L_e 0.0 L-Histidine exchange
# EX_hom__L_e 0.0 L-Homoserine exchange
# EX_hxa_e 0.0 Hexanoate (n-C6:0) exchange
# EX_hxan_e 0.0 Hypoxanthine exchange
# EX_idon__L_e 0.0 L-Idonate exchange
# EX_ile__L_e 0.0 L-Isoleucine exchange
# EX_imp_e 0.0 IMP exchange
# EX_indole_e 0.0 Indole exchange
# EX_inost_e 0.0 Myo-Inositol exchange
# EX_ins_e 0.0 Inosine exchange
# EX_isetac_e 0.0 Isethionic acid exchange
# EX_k_e -0.1917521012416176 K+ exchange
# EX_kdo2lipid4_e 0.0 KDO(2)-lipid IV(A) exchange
# EX_lac__D_e 0.0 D-lactate exchange
# EX_lac__L_e 0.0 L-Lactate exchange
# EX_lcts_e 0.0 Lactose exchange
# EX_leu__L_e 0.0 L-Leucine exchange
# EX_lipa_e 0.0 KDO(2)-lipid (A) exchange
# EX_lipa_cold_e 0.0 Cold adapted KDO(2)-lipid (A) exchange
# EX_lipoate_e 0.0 Lipoate exchange
# EX_lys__L_e 0.0 L-Lysine exchange
# EX_lyx__L_e 0.0 L-Lyxose exchange
# EX_mal__D_e 0.0 D-Malate exchange
# EX_mal__L_e 0.0 L-Malate exchange
# EX_malt_e 0.0 Maltose exchange
# EX_malthx_e 0.0 Maltohexaose exchange
# EX_maltpt_e 0.0 Maltopentaose exchange
# EX_malttr_e 0.0 Maltotriose exchange
# EX_maltttr_e 0.0 Maltotetraose exchange
# EX_man_e 0.0 D-Mannose exchange
# EX_man6p_e 0.0 D-Mannose 6-phosphate exchange
# EX_manglyc_e 0.0 2(alpha-D-Mannosyl)-D-glycerate exchange
# EX_melib_e 0.0 Melibiose exchange
# EX_meoh_e 1.9647436254539616e-06 Methanol exchange
# EX_met__D_e 0.0 D-Methionine exchange
# EX_met__L_e 0.0 L-Methionine exchange
# EX_metsox_R__L_e 0.0 L-methionine-R-sulfoxide exchange
# EX_metsox_S__L_e 0.0 L-Methionine S-oxide exchange
# EX_mg2_e -0.00852207547540656 Mg exchange
# EX_mincyc_e 0.0 Minocycline exchange
# EX_minohp_e 0.0 Myo-Inositol hexakisphosphate exchange
# EX_mmet_e 0.0 S-Methyl-L-methionine exchange
# EX_mn2_e -0.0006788189225943438 Mn2+ exchange
# EX_mnl_e 0.0 D-Mannitol exchange
# EX_mobd_e -0.00012672596384178053 Molybdate exchange
# EX_mso3_e 0.0 Methanesulfonate exchange
# EX_n2o_e 0.0 Nitrous oxide exchange
# EX_na1_e 0.0 Sodium exchange
# EX_nac_e 0.0 Nicotinate exchange
# EX_nh4_e -10.610425051825048 Ammonia exchange
# EX_ni2_e -0.0003173060955108148 Ni2+ exchange
# EX_nmn_e 0.0 NMN exchange
# EX_no_e 0.0 Nitric oxide exchange
# EX_no2_e 0.0 Nitrite exchange
# EX_no3_e 0.0 Nitrate exchange
# EX_novbcn_e 0.0 Novobiocin exchange
# EX_o16a4colipa_e 0.0 (O16 antigen)x4 core oligosaccharide lipid A exchange
# EX_o2_e -17.578933530254268 O2 exchange
# EX_o2s_e 0.0 Superoxide anion exchange
# EX_ocdca_e 0.0 Octadecanoate (n-C18:0) exchange
# EX_ocdcea_e 0.0 Octadecenoate (n-C18:1) exchange
# EX_octa_e 0.0 Octanoate (n-C8:0) exchange
# EX_orn_e 0.0 Ornithine exchange
# EX_orot_e 0.0 Orotate exchange
# EX_pacald_e 0.0 Phenylacetaldehyde exchange
# EX_peamn_e 0.0 Phenethylamine exchange
# EX_phe__L_e 0.0 L-Phenylalanine exchange
# EX_pheme_e 0.0 Protoheme exchange
# EX_pi_e -0.9476263040826497 Phosphate exchange
# EX_pnto__R_e 0.0 (R)-Pantothenate exchange
# EX_ppa_e 0.0 Propionate exchange
# EX_ppal_e 0.0 Propanal exchange
# EX_pppn_e 0.0 Phenylpropanoate exchange
# EX_ppt_e 0.0 Phosphonate exchange
# EX_pro__L_e 0.0 L-Proline exchange
# EX_progly_e 0.0 L-Prolinylglycine exchange
# EX_psclys_e 0.0 Psicoselysine exchange
# EX_pser__L_e 0.0 O-Phospho-L-serine exchange
# EX_ptrc_e 0.0 Putrescine exchange
# EX_pydam_e 0.0 Pyridoxamine exchange
# EX_pydx_e 0.0 Pyridoxal exchange
# EX_pydxn_e 0.0 Pyridoxine exchange
# EX_pyr_e 0.0 Pyruvate exchange
# EX_quin_e 0.0 Quinate exchange
# EX_r5p_e 0.0 Alpha-D-Ribose 5-phosphate exchange
# EX_rfamp_e 0.0 Rifampin exchange
# EX_rib__D_e 0.0 D-Ribose exchange
# EX_rmn_e 0.0 L-Rhamnose exchange
# EX_sbt__D_e 0.0 D-Sorbitol exchange
# EX_sel_e 0.0 Selenate exchange
# EX_ser__D_e 0.0 D-Serine exchange
# EX_ser__L_e 0.0 L-Serine exchange
# EX_skm_e 0.0 Shikimate exchange
# EX_slnt_e 0.0 Selenite exchange
# EX_so2_e 0.0 Sulfur dioxide exchange
# EX_so3_e 0.0 Sulfite exchange
# EX_so4_e -0.24776399488787243 Sulfate exchange
# EX_spmd_e 0.0 Spermidine exchange
# EX_succ_e 0.0 Succinate exchange
# EX_sucr_e 0.0 Sucrose exchange
# EX_sulfac_e 0.0 Sulfoacetate exchange
# EX_tartr__D_e 0.0 D-tartrate exchange
# EX_tartr__L_e 0.0 L-tartrate exchange
# EX_taur_e 0.0 Taurine exchange
# EX_tcynt_e 0.0 Thiocyanate exchange
# EX_thm_e 0.0 Thiamin exchange
# EX_thr__L_e 0.0 L-Threonine exchange
# EX_thrp_e 0.0 L-Threonine O-3-phosphate exchange
# EX_thym_e 0.0 Thymine exchange
# EX_thymd_e 0.0 Thymidine exchange
# EX_tma_e 0.0 Trimethylamine exchange
# EX_tmao_e 0.0 Trimethylamine N-oxide exchange
# EX_tre_e 0.0 Trehalose exchange
# EX_trp__L_e 0.0 L-Tryptophan exchange
# EX_tsul_e 0.0 Thiosulfate exchange
# EX_ttdca_e 0.0 Tetradecanoate (n-C14:0) exchange
# EX_ttdcea_e 0.0 Tetradecenoate (n-C14:1) exchange
# EX_ttrcyc_e 0.0 Tetracycline exchange
# EX_tungs_e 0.0 Tungstate exchange
# EX_tym_e 0.0 Tyramine exchange
# EX_tyr__L_e 0.0 L-Tyrosine exchange
# EX_tyrp_e 0.0 Phosphotyrosine exchange
# EX_uacgam_e 0.0 UDP-N-acetyl-D-glucosamine exchange
# EX_udpacgal_e 0.0 UDP-N-acetyl-D-galactosamine exchange
# EX_udpg_e 0.0 UDPglucose exchange
# EX_udpgal_e 0.0 UDPgalactose exchange
# EX_udpglcur_e 0.0 UDP-D-glucuronate exchange
# EX_ump_e 0.0 UMP exchange
# EX_ura_e 0.0 Uracil exchange
# EX_urea_e 0.0 Urea exchange
# EX_uri_e 0.0 Uridine exchange
# EX_val__L_e 0.0 L-Valine exchange
# EX_xan_e 0.0 Xanthine exchange
# EX_xmp_e 0.0 Xanthosine 5'-phosphate exchange
# EX_xtsn_e 0.0 Xanthosine exchange
# EX_xyl__D_e 0.0 D-Xylose exchange
# EX_xylu__L_e 0.0 L-Xylulose exchange
# EX_zn2_e -0.0003349887881399005 Zinc exchange
# 12DGR120tipp 0.0 1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C12:0)
# 12DGR140tipp 0.0 1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C14:0)
# 12DGR141tipp 0.0 1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C14:1)
# 12DGR160tipp 0.0 1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C16:0)
# 12DGR161tipp 0.0 1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C16:1)
# 12DGR180tipp 0.0 1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C18:0)
# 12DGR181tipp 0.0 1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C18:1)
# 12PPDRtex 0.0 (R)-Propane-1,2-diol transport via diffusion (extracellular to periplasm)
# 12PPDRtpp 0.0 (R)-Propane-1,2-diol facilitated transport (periplasm)
# 12PPDStex 0.0 (S)-Propane-1,2-diol transport via diffusion (extracellular to periplasm)
# 12PPDStpp 0.0 (S)-Propane-1,2-diol facilitated transport (periplasm)
# 14GLUCANabcpp 0.0 1,4-alpha-D-glucan transport via ABC system (periplasm)
# 14GLUCANtexi 0.0 1,4-alpha-D-glucan transport via diffusion (extracellular to periplasm) irreversible
# 23CAMPtex 0.0 23cAMP transport via diffusion (extracellular to periplasm)
# 23CCMPtex 0.0 23cCMP transport via diffusion (extracellular to periplasm)
# 23CGMPtex 0.0 23cGMP transport via diffusion (extracellular to periplasm)
# 23CUMPtex 0.0 23cUMP transport via diffusion (extracellular to periplasm)
# 23DAPPAt2pp 0.0 2,3-diaminopropionate transport in via proton symport
# 23DAPPAtex 0.0 2,3-diaminopropionate transport via diffusion
# 23PDE2pp 0.0 2',3'-cyclic-nucleotide phosphodiesterase (UMP) (periplasm)
# 23PDE4pp 0.0 2',3'-cyclic-nucleotide phosphodiesterase (CMP) (periplasm)
# 23PDE7pp 0.0 2',3'-cyclic-nucleotide phosphodiesterase (AMP) (periplasm)
# 23PDE9pp 0.0 2',3'-cyclic-nucleotide phosphodiesterase (GMP) (periplasm)
# 26DAHtex 0.0 Meso-2,6-Diaminoheptanedioate transport via diffusion (extracellular to periplasm)
# 2AGPA120tipp 0.0 2-Acyl-sn-glycero-3-phosphatidate (n-C12:0) transporter via facilitated diffusion (periplasm)
# 2AGPA140tipp 0.0 2-Acyl-sn-glycero-3-phosphatidate (n-C14:0) transporter via facilitated diffusion (periplasm)
# 2AGPA141tipp 0.0 2-Acyl-sn-glycero-3-phosphatidate (n-C14:1) transporter via facilitated diffusion (periplasm)
# 2AGPA160tipp 0.0 2-Acyl-sn-glycero-3-phosphatidate (n-C16:0) transporter via facilitated diffusion (periplasm)
# 2AGPA161tipp 0.0 2-Acyl-sn-glycero-3-phosphatidate (n-C16:1) transporter via facilitated diffusion (periplasm)
# 2AGPA180tipp 0.0 2-Acyl-sn-glycero-3-phosphatidate (n-C18:0) transporter via facilitated diffusion (periplasm)
# 2AGPA181tipp 0.0 2-Acyl-sn-glycero-3-phosphatidate (n-C18:1) transporter via facilitated diffusion (periplasm)
# 2AGPE120tipp 0.0 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C12:0) transporter via facilitated diffusion (periplasm)
# 2AGPE140tipp 0.0 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:0) transporter via facilitated diffusion (periplasm)
# 2AGPE141tipp 0.0 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1) transporter via facilitated diffusion (periplasm)
# 2AGPE160tipp 0.0 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0) transporter via facilitated diffusion (periplasm)
# 2AGPE161tipp 0.0 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:1) transporter via facilitated diffusion (periplasm)
# 2AGPE180tipp 0.0 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:0) transporter via facilitated diffusion (periplasm)
# 2AGPE181tipp 0.0 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:1) transporter via facilitated diffusion (periplasm)
# 2AGPEAT120 0.0 2-acyl-glycerophospho-ethanolamine acyltransferase (n-C12:0)
# 2AGPEAT140 0.0 2-acyl-glycerophospho-ethanolamine acyltransferase (n-C14:0)
# 2AGPEAT141 0.0 2-acyl-glycerophospho-ethanolamine acyltransferase (n-C14:1)
# 2AGPEAT160 0.0 2-acyl-glycerophospho-ethanolamine acyltransferase (n-C16:0)
# 2AGPEAT161 0.0 2-acyl-glycerophospho-ethanolamine acyltransferase (n-C16:1)
# 2AGPEAT180 0.0 2-acyl-glycerophospho-ethanolamine acyltransferase (n-C18:0)
# 2AGPEAT181 0.0 2-acyl-glycerophospho-ethanolamine acyltransferase (n-C18:1)
# 2AGPG120tipp 0.0 2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0) transporter via facilitated diffusion (periplasm)
# 2AGPG140tipp 0.0 2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0) transporter via facilitated diffusion (periplasm)
# 2AGPG141tipp 0.0 2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:1) transporter via facilitated diffusion (periplasm)
# 2AGPG160tipp 0.0 2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0) transporter via facilitated diffusion (periplasm)
# 2AGPG161tipp 0.0 2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1) transporter via facilitated diffusion (periplasm)
# 2AGPG180tipp 0.0 2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0) transporter via facilitated diffusion (periplasm)
# 2AGPG181tipp 0.0 2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1) transporter via facilitated diffusion (periplasm)
# 2AGPGAT120 0.0 2-acyl-glycerophospho-glycerol acyltransferase (n-C12:0)
# 2AGPGAT140 0.0 2-acyl-glycerophospho-glycerol acyltransferase (n-C14:0)
# 2AGPGAT141 0.0 2-acyl-glycerophospho-glycerol acyltransferase (n-C14:1)
# 2AGPGAT160 0.0 2-acyl-glycerophospho-glycerol acyltransferase (n-C16:0)
# 2AGPGAT161 0.0 2-acyl-glycerophospho-glycerol acyltransferase (n-C16:1)
# 2AGPGAT180 0.0 2-acyl-glycerophospho-glycerol acyltransferase (n-C18:0)
# 2AGPGAT181 0.0 2-acyl-glycerophospho-glycerol acyltransferase (n-C18:1)
# 2DGULRGx 0.0 2-Dehydro-L-gulonate reductase to gluconate (NADH)
# 2DGULRGy 0.0 2-Dehydro-L-gulonate reductase to gluconate (NADPH)
# 2DGULRx 0.0 2-dehydro-L-gulonate reductase (NADH)
# 2DGULRy 0.0 2-dehydro-L-gulonate reductase (NADPH)
# 2MAHMP 0.0 2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphatase
# 34dhpactex 0.0 Dihydroxyphenylacetaldehyde transport via diffusion (extracellular to periplasm)
# 3AMACHYD 0.0 3-aminoacrylate hydrolase
# 3AMPtex 0.0 3AMP transport via diffusion (extracellular to periplasm)
# 3CMPtex 0.0 3CMP transport via diffusion (extracellular to periplasm)
# 3GMPtex 0.0 3GMP transport via diffusion (extracellular to periplasm)
# 3HAD100 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C10:0)
# 3HAD120 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C12:0)
# 3HAD121 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C12:1)
# 3HAD140 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C14:0)
# 3HAD141 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C14:1)
# 3HAD160 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C16:0)
# 3HAD161 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C16:1)
# 3HAD180 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C18:0)
# 3HAD181 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C18:1)
# 3HAD40 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C4:0)
# 3HAD60 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C6:0)
# 3HAD80 0.0 3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C8:0)
# 3HCINNMH 0.0 3-hydroxycinnamate hydroxylase
# 3HPPPNH 0.0 3-(3-hydroxy-phenyl)propionate hydroxylase
# 3HPPtex 0.0 3-hydroxypropionate transport via diffusion (extracellular to periplasm)
# 3HPPtpp 0.0 3-hydroxypropionate transport via proton symport (periplasm)
# 3KGK 0.0 3-keto-L-gulonate kinase
# 3NTD2pp 0.0 3'-nucleotidase (UMP) (periplasm)
# 3NTD4pp 0.0 3'-nucleotidase (CMP) (periplasm)
# 3NTD7pp 0.0 3'-nucleotidase (AMP) (periplasm)
# 3NTD9pp 0.0 3'-nucleotidase (GMP) (periplasm)
# 3OAR100 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C10:0)
# 3OAR120 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C12:0)
# 3OAR121 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C12:1)
# 3OAR140 0.07645210395366457 3-oxoacyl-[acyl-carrier-protein] reductase (n-C14:0)
# 3OAR141 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C14:1)
# 3OAR160 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C16:0)
# 3OAR161 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C16:1)
# 3OAR180 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C18:0)
# 3OAR181 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C18:1)
# 3OAR40 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C4:0)
# 3OAR60 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C6:0)
# 3OAR80 0.0 3-oxoacyl-[acyl-carrier-protein] reductase (n-C8:0)
# 3OAS100 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C10:0)
# 3OAS120 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C12:0)
# 3OAS121 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C12:1)
# 3OAS140 0.07645210395366457 3-oxoacyl-[acyl-carrier-protein] synthase (n-C14:0)
# 3OAS141 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C14:1)
# 3OAS160 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C16:0)
# 3OAS161 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C16:1)
# 3OAS180 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C18:0)
# 3OAS181 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C18:1)
# 3OAS60 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C6:0)
# 3OAS80 0.0 3-oxoacyl-[acyl-carrier-protein] synthase (n-C8:0)
# 3OXCOAT 0.0 3-oxoadipyl-CoA thiolase
# 3PEPTabcpp 0.0 Tripeptide (LalaDgluMdap) transport via ABC system (periplasm)
# 3PEPTtex 0.0 LalaDgluMdap (tripeptide) transport via diffusion (extracellular to periplasm)
# 3UMPtex 0.0 3UMP transport via diffusion (extracellular to periplasm)
# 42A12BOOXpp 0.0 4-(2-Aminoethyl)-1,2-benzenediol:oxygen oxidoreductase(deaminating)(flavin-containing)
# 4HOXPACDtex 0.0 4-hydroxyphenylacetaldehyde transport via diffusion (extracellular to periplasm)
# 4HTHRS 0.0 4-Hydroxy-L-threonine synthase
# 4PCP 0.0 Tetrapeptide L,D-carboxypeptidase
# 4PCPpp 0.0 Tetrapeptide L,D-carboxypeptidase (periplasm)
# 4PEPTabcpp 0.0 Tetrapeptide (LalaDgluMdapDala) transport via ABC system (periplasm)
# 4PEPTtex 0.0 LalaDgluMdapDala (pentapeptide) transport via diffusion (extracellular to periplasm)
# 5DGLCNR 0.0 5-dehydro-D-gluconate reductase
# 5DGLCNt2rpp 0.0 5-Dehydro-D-gluconate transport via proton symport, reversible (periplasm)
# 5DGLCNtex 0.0 5-Dehydro-D-gluconate transport via diffusion (extracellular to periplasm)
# 5DOAN 0.0002210336578635639 5'-deoxyadenosine nuclosidase
# 5MTRtex 0.0 5-Methylthio-D-ribose transport via proton diffusion (extracellular to periplasm)
# 5MTRtpp 0.0 5-Methylthio-D-ribose transport via proton symport (periplasm)
# A5PISO 0.038226051976832286 Arabinose-5-phosphate isomerase
# AACPS1 0.0 Acyl-[acyl-carrier-protein] synthetase (n-C14:0)
# AACPS2 0.0 Acyl-[acyl-carrier-protein] synthetase  (n-C14:1)
# AACPS3 0.1253781497147191 Acyl-[acyl-carrier-protein] synthetase  (n-C16:0)
# AACPS4 0.1477762270448943 Acyl-[acyl-carrier-protein] synthetase  (n-C16:1)
# AACPS5 0.0 Acyl-[acyl-carrier-protein] synthetase  (n-C18:1)
# AACPS6 0.0 Acyl-[acyl-carrier-protein] synthetase  (n-C18:0)
# AACPS7 0.07645210395366457 Acyl-[acyl-carrier-protein] synthetase  (n-C12:0)
# AACPS8 0.0 Acyl-[acyl-carrier-protein] synthetase  (n-C10:0)
# AACPS9 0.0 Acyl-[acyl-carrier-protein] synthetase  (n-C8:0)
# AACTOOR 0.0 Aminoacetone:oxygen oxidoreductase(deaminating)(flavin-containing)
# AADDGT 0.0 DTDP-N-4-acetamido-4,6-dideoxy-D-galactose transferase
# AAMYL 0.0 Alpha-amylase
# AAMYLpp 0.0 Alpha-amylase (periplasm)
# AB6PGH 0.0 Arbutin 6-phosphate glucohydrolase
# ABTA 0.0 4-aminobutyrate transaminase
# ABUTD 0.0 Aminobutyraldehyde dehydrogenase
# ABUTt2pp 0.0 4-aminobutyrate transport in via proton symport (periplasm)
# ABUTtex 0.0 4-aminobutyrate transport via diffusion (extracellular to periplasm)
# ACACCT 0.0 Acetyl-CoA:acetoacetyl-CoA transferase
# ACACT1r 0.349606480713278 Acetyl-CoA C-acetyltransferase
# ACACT2r 0.349606480713278 Acetyl-CoA C-acyltransferase (butanoyl-CoA) (r)
# ACACT3r 0.349606480713278 Acetyl-CoA C-acyltransferase (hexanoyl-CoA) (r)
# ACACT4r 0.349606480713278 Acetyl-CoA C-acyltransferase (octanoyl-CoA) (r)
# ACACT5r 0.349606480713278 Acetyl-CoA C-acyltransferase (decanoyl-CoA) (r)
# ACACT6r 0.2731543767596134 Acetyl-CoA C-acyltransferase (dodecanoyl-CoA) (r)
# ACACT7r 0.2731543767596134 Acetyl-CoA C-acyltransferase (tetradecanoyl-CoA) (r)
# ACACT8r 0.0 Acetyl-CoA acyltransferase (hexadecanoyl-CoA), (r)
# ACACt2pp 0.0 Acetoacetate transport via proton symport  (periplasm)
# ACACtex 0.0 Acetoacetate transport via diffusion (extracellular to periplasm)
# ACALD 0.0 Acetaldehyde dehydrogenase (acetylating)
# ACALDtex 0.0 Acetaldehyde transport via diffusion (extracellular to periplasm)
# ACALDtpp 0.0 Acetaldehyde reversible transport (periplasm)
# ACANTHAT 0.0 Acetyl-CoA:anthranilate acetyltransferase
# ACBIPGT 0.0 Adenosyl cobinamide phosphate guanyltransferase
# ACCOAC 0.07645799818454097 Acetyl-CoA carboxylase
# ACCOAL 0.0 Acetate-CoA ligase (ADP-forming)
# ACGAL1PPpp 0.0 N-acetyl-D-galactosamine 1-phosphatase (periplasm)
# ACGAL1Ptex 0.0 N-acetyl-D-galactosamine 1-phosphate transport via diffusion (extracellular to periplasm)
# ACGALtex 0.0 N-acetyl-D-galactosamine transport via diffusion (extracellular to periplasm)
# ACGAM1PPpp 0.0 N-acetyl-D-glucosamine 1-phosphatase (periplasm)
# ACGAM1Ptex 0.0 N-acetyl-D-glucosamine 1-phosphate transport via diffusion (extracellular to periplasm)
# ACGAMK 0.0 N-acetylglucosamine kinase
# ACGAMT 0.0 UDP-N-acetylglucosamine:undecaprenylphosphate N-acetylglucosamine -1-phosphate transferase
# ACGAptspp 0.0 N-Acetyl-D-glucosamine transport via PEP:Pyr PTS  (periplasm)
# ACGAtex 0.0 N-Acetyl-D-glucosamine transport via diffusion (extracellular to periplasm)
# ACGK 0.29057772323013914 Acetylglutamate kinase
# ACGS 0.29057772323013914 N-acetylglutamate synthase
# ACHBS 0.28540750037975704 2-aceto-2-hydroxybutanoate synthase
# ACKr 0.0 Acetate kinase
# ACLS 0.8588572223410056 Acetolactate synthase
# ACM6PH 0.0 N-acetylmuramate 6-phosphate hydrolase
# ACMAMUT 0.0 UDP-N-acetyl-D-mannosaminuronic acid transferase
# ACMANAptspp 0.0 N-acetyl-D-mannosamine transport via PTS  (periplasm)
# ACMANAtex 0.0 N-acetyl-D-mannosamine transport via diffusion (extracellular to periplasm)
# ACMUMptspp 0.0 N-acetylmuramate transport via PEP:Pyr PTS (periplasm)
# ACMUMtex 0.0 N-acetylmuramate transport via diffusion (extracellular to periplasm)
# ACNAMt2pp 0.0 N-acetylneuraminate proton symport (periplasm)
# ACNAMtex 0.0 N-acetylneuraminate transport via diffusion (extracellular to periplasm)
# ACNML 0.0 N-Acetylneuraminate lyase
# ACOAD1f -0.349606480713278 Acyl-CoA dehydrogenase (butanoyl-CoA)
# ACOAD2f -0.349606480713278 Acyl-CoA dehydrogenase (hexanoyl-CoA)
# ACOAD3f -0.349606480713278 Acyl-CoA dehydrogenase (octanoyl-CoA)
# ACOAD4f -0.349606480713278 Acyl-CoA dehydrogenase (decanoyl-CoA)
# ACOAD5f -0.349606480713278 Acyl-CoA dehydrogenase (dodecanoyl-CoA)
# ACOAD6f -0.2731543767596134 Acyl-CoA dehydrogenase (tetradecanoyl-CoA)
# ACOAD7f -0.1253781497147191 Acyl-CoA dehydrogenase (hexadecanoyl-CoA)
# ACOAD8f 0.0 Acyl-CoA dehydrogenase (octadecanoyl-CoA)
# ACOATA 0.0 Acetyl-CoA ACP transacylase
# ACODA 0.29057772323013914 Acetylornithine deacetylase
# ACOLIPAabctex 0.0 Arabinose modified core oligosaccharide lipid A transport via ABC system (periplasm to extracellular)
# ACONIs 0.0 Aconitate isomerase (spontaneous)
# ACONMT 0.0 Trans-aconitate methyltransferase
# ACONTa 4.85777664422629 Aconitase (half-reaction A, Citrate hydro-lyase)
# ACONTb 4.85777664422629 Aconitase (half-reaction B, Isocitrate hydro-lyase)
# ACOTA -0.29057772323013914 Acetylornithine transaminase
# ACPPAT120 0.0 Acyl-(acyl carrier protein):phosphate acyltransferase (C12:0)
# ACPPAT140 0.0 Acyl-(acyl carrier protein):phosphate acyltransferase (C14:0)
# ACPPAT141 0.0 Acyl-(acyl carrier protein):phosphate acyltransferase (C14:1)
# ACPPAT160 0.06268907485735956 Acyl-(acyl carrier protein):phosphate acyltransferase (C16:0)
# ACPPAT161 0.07388811352244715 Acyl-(acyl carrier protein):phosphate acyltransferase (C16:1)
# ACPPAT180 0.0 Acyl-(acyl carrier protein):phosphate acyltransferase (C18:0)
# ACPPAT181 0.0 Acyl-(acyl carrier protein):phosphate acyltransferase (C18:1)
# ACPS1 0.0 Acyl-carrier protein synthase
# ACS 0.5723062411712342 Acetyl-CoA synthetase
# ACSERtex 0.0 O-Acetyl-L-serine transport via diffusion (extracellular to periplasm)
# ACSERtpp 0.0 O-Acetyl-L-serine export via facilitated transport
# ACt2rpp -0.005113245285243936 Acetate reversible transport via proton symport (periplasm)
# ACt4pp 0.005113245285243936 Na+/Acetate symport (periplasm)
# ACtex 0.0 Acetate transport via diffusion (extracellular to periplasm)
# ADA 0.0 Adenosine deaminase
# ADCL 0.0006572067427141622 4-aminobenzoate synthase
# ADCS 0.0006572067427141622 4-amino-4-deoxychorismate synthase
# ADD 0.0 Adenine deaminase
# ADEt2rpp 0.0 Adenine transport via proton symport (reversible) (periplasm)
# ADEtex 0.0 Adenine transport via diffusion (extracellular to periplasm)
# ADK1 3.1516570380524387 Adenylate kinase
# ADK3 0.0 Adentylate kinase (GTP)
# ADK4 0.0 Adentylate kinase (ITP)
# ADMDC 0.0 Adenosylmethionine decarboxylase
# ADNCYC 0.0 Adenylate cyclase
# ADNK1 0.0 Adenosine kinase
# ADNUC 0.0 Adenosine hydrolase
# ADNt2pp_copy1 0.0 None
# ADNt2pp_copy2 0.0 None
# ADNtex 0.0 Adenosine transport via diffusion (extracellular to periplasm)
# ADOCBIK 0.0 Adenosyl cobinamide kinase
# ADOCBLS 0.0 Adenosylcobalamin 5'-phosphate synthase
# ADOCBLabcpp 0.0 Adenosylcobalamin transport via ABC system (periplasm)
# ADOCBLtonex 0.0 Adenosylcobalimin transport via ton system (extermal)
# ADPRDP 0.0 ADPribose diphosphatase
# ADPT 0.000661136229965261 Adenine phosphoribosyltransferase
# ADSK 0.24350246596426278 Adenylyl-sulfate kinase
# ADSL1r 0.2937655197624327 Adenylsuccinate lyase
# ADSL2r 0.4401173076788727 Adenylosuccinate lyase
# ADSS 0.2937655197624327 Adenylosuccinate synthase
# AGDC 0.0 N-acetylglucosamine-6-phosphate deacetylase
# AGM3PA 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide amidase
# AGM3PApp 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide amidase (periplasm)
# AGM3PH 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide beta -1,4-N-acetylglucosaminidase
# AGM3Pt2pp 0.0 GlcNAc-anhMurNAc tripeptide transport in via proton symport (periplasm)
# AGM4PA 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide amidase
# AGM4PApp 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide amidase (periplasm)
# AGM4PCP 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide L,D-carboxypeptidase
# AGM4PCPpp 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide L,D-carboxypeptidase (periplasmic)
# AGM4PH 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide beta -1,4-N-acetylglucosaminidase
# AGM4Pt2pp 0.0 GlcNAc-anhMurNAc tetrapeptide transport in via proton symport (periplasm)
# AGMH 0.0 N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl beta -1,4-N-acetylglucosaminidase
# AGMHE 0.0 ADP-D-glycero-D-manno-heptose epimerase
# AGMT 0.0 Agmatinase
# AGMt2pp 0.0 GlcNAc-anhMurNAc transport in via proton symport (periplasm)
# AGMtex 0.0 Agmatine transport via diffusion (extracellular to periplasm)
# AGPAT120 0.0 1-tetradecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C12:0)
# AGPAT140 0.0 1-tetradecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C14:0)
# AGPAT141 0.0 1-tetradec-7-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C14:1)
# AGPAT160 0.06268907485735956 1-hexadecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C16:0)
# AGPAT161 0.07388811352244715 1-hexadec-7-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C16:1)
# AGPAT180 0.0 1-octadecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C18:0)
# AGPAT181 0.0 1-octadec-7-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C18:1)
# AGPR -0.29057772323013914 N-acetyl-g-glutamyl-phosphate reductase
# AGt3 0.0 Silver transport out via proton antiport
# AHCYSNS 0.0004401025721016971 S-adenosylhomocysteine nucleosidase
# AICART 0.5331852484730014 Phosphoribosylaminoimidazolecarboxamide formyltransferase
# AIRC2 0.4401173076788727 Phosphoribosylaminoimidazole carboxylase
# AIRC3 -0.4401173076788727 Phosphoribosylaminoimidazole carboxylase (mutase rxn)
# AKGDH 3.801538330156747 2-Oxogluterate dehydrogenase
# AKGt2rpp 0.0 2-oxoglutarate reversible transport via symport (periplasm)
# AKGtex 0.0 Alpha-ketoglutarate transport via diffusion (extracellular to periplasm)
# ALAALAD 0.0 D-alanine-D-alanine dipeptidase
# ALAALAabcpp 0.0 D-alanyl-D-alanine (DalaDala) transport via ABC system (periplasm)
# ALAALAr 0.027298147932057346 D-alanine-D-alanine ligase (reversible)
# ALAALAtex 0.0 D-alanyl-D-alanine (DalaDala) transport via diffusion (extracellular to periplasm)
# ALAGLUE 0.0 L-alanyl-gamma-glutamate epimerase
# ALAR 0.04094722189808602 Alanine racemase
# ALATA_D2 0.0 D-alanine transaminase
# ALATA_L -0.9868101685768814 L-alanine transaminase
# ALATA_L2 0.0 Alanine transaminase
# ALATRS 0.0 Alanyl-tRNA synthetase
# ALAabcpp 0.0 L-alanine transport via ABC system (periplasm)
# ALAt2pp_copy1 0.0 None
# ALAt2pp_copy2 0.0 None
# ALAt4pp 0.0 L-alanine transport in via sodium symport (periplasm)
# ALAtex 0.0 L-alanine transport via diffusion (extracellular to periplasm)
# ALCD19 0.0 Alcohol dehydrogenase (glycerol)
# ALCD2x 0.0 Alcohol dehydrogenase (ethanol)
# ALDD19xr 0.0 Aldehyde dehydrogenase (phenylacetaldehyde, NAD)
# ALDD2x 0.0 Aldehyde dehydrogenase (acetaldehyde, NAD)
# ALDD2y 0.0 Aldehyde dehydrogenase (acetaldehyde, NADP)
# ALDD3y 0.0 Aldehyde dehydrogenase (propanal, NADP)
# ALDD4 0.0 Aldehyde dehydrogenase (butanal, NAD)
# ALLK 0.0 Allose kinase
# ALLPI 0.0 Allose 6-phosphate isomerase
# ALLTAMH 0.0 Allantoate amidohydrolase
# ALLTN 0.0 Allantoinase
# ALLTNt2rpp 0.0 Allantoin transport in via proton symport (periplasm)
# ALLTNtex 0.0 Allantoin transport via diffusion (extracellular to periplasm)
# ALLULPE 0.0 Allulose 6-phosphate epimerase
# ALLabcpp 0.0 D-allose transport via ABC system (periplasm)
# ALLtex 0.0 Allose transport via diffusion (extracellular to periplasm)
# ALPATE160pp 0.0 Apolipoprotein N-acyltransferase (phosphatidylethanolamine, periplasm)
# ALPATG160pp 0.0 Apolipoprotein N-acyltransferase (phosphatidylglycerol, periplasm)
# ALR2 0.0 Aldose reductase (methylglyoxal)
# ALR4x 0.0 Aldose reductase (acetol)
# ALTRH 0.0 Altronate hydrolase
# AM3PA 0.0 Anhydrous-N-Acetylmuramyl-tripeptide amidase
# AM4PA 0.0 Anhydrous-N-Acetylmuramyl-tetrapeptide amidase
# AM4PCP 0.0 Anhydrous-N-Acetylmuramyl-tetrapeptide L,D-carboxypeptidase
# AMALT1 0.0 Amylomaltase (maltotriose)
# AMALT2 0.0 Amylomaltase (maltotetraose)
# AMALT3 0.0 Amylomaltase (maltopentaose)
# AMALT4 0.0 Amylomaltase (maltohexaose)
# AMANAPEr 0.0 N-acetylmannosamine 6-phosphate epimerase
# AMANK 0.0 N-acetyl-D-mannosamine kinase
# AMAOTr 1.9647436254539616e-06 Adenosylmethionine-8-amino-7-oxononanoate transaminase
# AMMQLT8 0.0 S-adenosylmethione:2-demthylmenaquinole methyltransferase (menaquinone 8)
# AMPMS2 0.00021906891423811674 4-amino-2-methyl-5-phosphomethylpyrimidine synthetase
# AMPN 0.0 AMP nucleosidase
# AMPTASECG 0.0 Alanyl aminopeptidase (cys-gly)
# AMPTASEPG 0.0 Aminopeptidase (pro-gly)
# AMPtex 0.0 AMP transport via diffusion (extracellular to periplasm)
# ANHGMtex 0.0 GlcNAc-anhMurNAc transport via diffusion (extracellular to periplasm)
# ANHMK 0.0 1,6-anhydrous-N-Acetylmuramate kinase
# ANPRT 0.05584096095083978 Anthranilate phosphoribosyltransferase
# ANS 0.05584096095083978 Anthranilate synthase
# AOBUTDs 0.0 L-2-amino-3-oxobutanoate decarboxylation (spontaneous)
# AOXSr2 1.9647436254539616e-06 8-amino-7-oxononanoate synthase
# AP4AH 0.0 Ap4A hydrolase
# AP4AS 0.0 Ap4A synthetase
# AP5AH 0.0 Ap5A hydrolase
# APCS 0.0 Aminopropylcadaverine synthase
# APG3PAT120 0.0 Acyl-phosphate:glycerol-3-phosphate acyltransferase (C12:0)
# APG3PAT140 0.0 Acyl-phosphate:glycerol-3-phosphate acyltransferase (C14:0)
# APG3PAT141 0.0 Acyl-phosphate:glycerol-3-phosphate acyltransferase (C14:1)
# APG3PAT160 0.06268907485735956 Acyl-phosphate:glycerol-3-phosphate acyltransferase (C16:0)
# APG3PAT161 0.07388811352244715 Acyl-phosphate:glycerol-3-phosphate acyltransferase (C16:1)
# APG3PAT180 0.0 Acyl-phosphate:glycerol-3-phosphate acyltransferase (C18:0)
# APG3PAT181 0.0 Acyl-phosphate:glycerol-3-phosphate acyltransferase (C18:1)
# APH120 0.0 Acylphosphatase (C12:0)
# APH140 0.0 Acylphosphatase (C14:0)
# APH141 0.0 Acylphosphatase (C14:1)
# APH160 0.0 Acylphosphatase (C16:0)
# APH161 0.0 Acylphosphatase (C16:1)
# APH180 0.0 Acylphosphatase (C18:0)
# APH181 0.0 Acylphosphatase (C18:1)
# APPLDHr 0.0 Aminopropanol dehydrogenase reversible
# APRAUR 0.0004381378284762072 5-amino-6-(5-phosphoribosylamino)uracil reductase
# ARAI 0.0 L-arabinose isomerase
# ARBTNR1 0.0 Aerobactin reductase
# ARBTNR2 0.0 Aerobactin reductase
# ARBTNR3 0.0 Aerobactin reductase
# ARBTNabcpp 0.0 Aerobactin transport via ABC system (periplasm)
# ARBTNexs 0.0 Aerobactin Fe-loading reaction (spontaneous)
# ARBTNtex 0.0 Aerobactin secretion (to extracellular)
# ARBTNtonex 0.0 Aerobactin transport via ton system (extracellular)
# ARBTNtpp 0.0 Aerobactin secretion (to periplasm)
# ARBTptspp 0.0 Arbutin transport via PEP:Pyr PTS (periplasm)
# ARBTtex 0.0 Arbutin transport via diffusion (extracellular to periplasm)
# ARBabcpp 0.0 L-arabinose transport via ABC system (periplasm)
# ARBt2rpp 0.0 L-arabinose transport via proton symport (periplasm)
# ARBt3ipp 0.0 L-arabinose transport via proton antiport (periplasm)
# ARBtex 0.0 L-arabinose transport via diffusion (extracellular to periplasm)
# ARGAGMt7pp 0.0 Arginine/agmatine antiport (periplasm)
# ARGDC 0.0 Arginine decarboxylase
# ARGDCpp 0.0 Arginine decarboxylase
# ARGORNt7pp 0.0 Arginine/ornithine antiporter (periplasm)
# ARGSL 0.29057772323013914 Argininosuccinate lyase
# ARGSS 0.29057772323013914 Argininosuccinate synthase
# ARGTRS 0.0 Arginyl-tRNA synthetase
# ARGabcpp 0.0 L-arginine transport via ABC system (periplasm)
# ARGt3pp 0.0 L-arginine transport out via proton antiport (cytoplasm to periplasm)
# ARGtex 0.0 L-arginine transport via diffusion (extracellular to periplasm)
# ASAD -1.0502301280629098 Aspartate-semialdehyde dehydrogenase
# ASCBPL 0.0 L-ascorbate 6-phosphate lactonase
# ASCBptspp 0.0 L-ascorbate transport via PEP:Pyr PTS (periplasm)
# ASCBtex 0.0 L-ascorbate transport via diffusion (extracellular to periplasm)
# ASNN 0.0 L-asparaginase
# ASNNpp 0.0 L-asparaginase
# ASNS1 0.0 Asparagine synthase (glutamine-hydrolysing)
# ASNS2 0.23680563731690238 Asparagine synthetase
# ASNTRS 0.0 Asparaginyl-tRNA synthetase
# ASNabcpp 0.0 L-asparagine transport via ABC system (periplasm)
# ASNt2rpp 0.0 L-asparagine reversible transport via proton symport (periplasm)
# ASNtex 0.0 L-asparagine transport via diffusion (extracellular to periplasm)
# ASO3t8pp 0.0 Arsenite efflux via ATP hydrolysis (periplasm)
# ASO3tex 0.0 Arsenite transport via diffusion (extracellular to periplasm)
# ASP1DC 0.0005658461641313069 Aspartate 1-decarboxylase
# ASPCT 0.3249636837910217 Aspartate carbamoyltransferase
# ASPK 1.0502301280629098 Aspartate kinase
# ASPO3 0.0 L-aspartate oxidase
# ASPO4 0.0 L-aspartate oxidase
# ASPO5 0.0 L-aspartate oxidase
# ASPO6 0.002237842989389011 L-aspartate oxidase
# ASPT 0.0 L-aspartase
# ASPTA -2.8760693263127015 Aspartate transaminase
# ASPTRS 0.0 Aspartyl-tRNA synthetase
# ASPabcpp 0.0 L-aspartate transport via ABC system (periplasm)
# ASPt2_2pp 0.0 Aspartate transport via proton symport (2 H) (periplasm)
# ASPt2_3pp 0.0 L-asparate transport via proton symport (3 H) (periplasm)
# ASPt2pp_copy1 0.0 None
# ASPt2pp_copy2 0.0 None
# ASPtex 0.0 L-aspartate transport via diffusion (extracellular to periplasm)
# ASR 0.0 Arsenate reductase
# AST 0.0 Arginine succinyltransferase
# ATHRDHr 0.0 L-allo-threonine dehydrogenase
# ATPHs 0.0 ATP amine hydrolysis (spontaneous)
# ATPM 3.15 ATP maintenance requirement
# ATPPRT 0.09306794079412872 ATP phosphoribosyltransferase
# ATPS4rpp 55.81524739984229 ATP synthase (four protons for one ATP) (periplasm)
# BALAt2pp 0.0 Beta-alanine transport in via proton symport (periplasm)
# BALAtex 0.0 Beta-alanine transport via diffusion (extracellular to periplasm)
# BETALDHx 0.0 Betaine-aldehyde dehydrogenase
# BETALDHy 0.0 Betaine-aldehyde dehydrogenase
# BMOCOS 0.00011984936115269167 Bis-molybdenum cofactor synthase
# BMOGDS1 0.00011984936115269167 Bis-molybdopterin guanine dinucleotide synthase (single GDP)
# BMOGDS2 0.00011984936115269167 Bis-molybdopterin guanine dinucleotide synthase
# BPNT 0.24350246596426278 3',5'-bisphosphate nucleotidase
# BSORx 0.0 Biotin sulfoxide reductase
# BSORy 0.0 Biotin sulfoxide reductase
# BTNt2ipp 0.0 Biotin transport via proton symport (periplasm)
# BTNtex 0.0 Biotin transport via diffusion (extracellular to periplasm)
# BTS5 1.9647436254539616e-06 Biotin synthase
# BUTCT 0.0 Acetyl-CoA:butyrate-CoA transferase
# BUTSO3abcpp 0.0 Butanesulfonate transport via ABC system (periplasm)
# BUTSO3tex 0.0 Butanesulfonate transport via diffusion (extracellular to periplasm)
# BUTt2rpp 0.0 Butyrate transport via proton symport, reversible (periplasm)
# BUTtex 0.0 Butyrate transport via diffusion (extracellular to periplasm)
# BWCOGDS1 0.0 Tungsten bispterin guanine dinucleotide synthase (single GDP)
# BWCOGDS2 0.0 Tungsten bispterin guanine dinucleotide synthase
# BWCOS 0.0 Tungsten bispterin cofactor synthase
# CA2t3pp 0.0 Calcium (Ca+2) transport out via proton antiport (periplasm)
# CA2tex 0.005113245285243936 Calcium (Ca+2) transport via diffusion (extracellular to periplasm)
# CADVtpp 0.0 Lysine/Cadaverine antiporter (periplasm)
# CAT 0.0 Catalase
# CAt6pp -0.005113245285243936 Calcium / sodium antiporter (1:1)
# CBIAT 0.0 Cobinamide adenyltransferase
# CBItonex 0.0 Cobinamide transport via ton system (extermal)
# CBIuabcpp 0.0 Cobinamide transport via ABC system (uptake, periplasm)
# CBL1abcpp 0.0 Cob(1)alamin transport via ABC system (periplasm)
# CBL1tonex 0.0 Cob(1)alamin transport via ton system (extermal)
# CBLAT 0.0 Cob(I)alamin adenosyltransferase
# CBMD 0.0 Carbamate deaminase
# CBMKr 0.6155414070211609 Carbamate kinase
# CBPS 0.0 Carbamoyl-phosphate synthase (glutamine-hydrolysing)
# CCGS 0.0 7-cyano-7-carbaguanine synthase
# CD2abcpp 0.0 Cadmium (Cd+2) ABC transporter (periplasm)
# CD2t3pp 0.0 Cadmium (Cd+2) transport out via proton antiport (periplasm)
# CD2tex 0.0 Cadmium (Cd+2) transport via diffusion (extracellular to periplasm)
# CD2tpp 0.0 Cadmium (+2) transport in via permease (no H+)
# CDAPPA120 0.0 CDP-Diacylglycerol pyrophostatase (n-C12:0)
# CDAPPA140 0.0 CDP-Diacylglycerol pyrophostatase (n-C14:0)
# CDAPPA141 0.0 CDP-Diacylglycerol pyrophostatase (n-C14:1)
# CDAPPA160 0.0 CDP-Diacylglycerol pyrophostatase (n-C16:0)
# CDAPPA161 0.0 CDP-Diacylglycerol pyrophostatase (n-C16:1)
# CDAPPA180 0.0 CDP-Diacylglycerol pyrophostatase (n-C18:0)
# CDAPPA181 0.0 CDP-Diacylglycerol pyrophostatase (n-C18:1)
# CDGR 0.0 7-cyano-7-deazaguanine reductase
# CDGS 0.0 7-deaza-7-carboxyguanine synthase
# CDPMEK 0.002346886260604752 4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol kinase
# CFAS160E 0.0 Cyclopropane fatty acid synthase (Phosphatidylethanolamine, n-C16:0)
# CFAS160G 0.0 Cyclopropane fatty acid synthase (Phosphatidylglycerol, n-C16:0)
# CFAS180E 0.0 Cyclopropane fatty acid synthase (Phosphatidylethanolamine, n-C18:0)
# CFAS180G 0.0 Cyclopropane fatty acid synthase (Phosphatidylglycerol, n-C18:0)
# CGLYabcpp 0.0 L-Cysteinylglycine (Cys-Gly) transport via ABC system (periplasm)
# CGLYtex 0.0 L-Cysteinylglycine transport via diffusion (extracellular to periplasm)
# CHLabcpp 0.0 Choline transport via ABC system (periplasm)
# CHLt2pp 0.0 Choline transport via proton symport (periplasm)
# CHLtex 0.0 Choline transport via diffusion (extracellular to periplasm)
# CHOLD 0.0 Choline dehydrogenase
# CHORM 0.317683326286902 Chorismate mutase
# CHORS 0.3744005628946941 Chorismate synthase
# CHRPL 0.00021906891423811674 Chorismate pyruvate lyase
# CHTBSptspp 0.0 Chitobiose transport via PEP:Pyr PTS (periplasm)
# CHTBStex 0.0 Chitobiose transport via diffusion (extracellular to periplasm)
# CINNDO 0.0 Cinnamate dioxygenase
# CITL 0.0 Citrate lyase
# CITt3pp 0.0 Citrate transport out via proton antiport (periplasm)
# CITt7pp 0.0 Citrate transport via succinate antiport (periplasm)
# CITtex 0.0 Citrate transport via diffusion (extracellular to periplasm)
# CLIPAabctex 0.0 Cold lipid A transport via ABC system (periplasm to extracellular)
# CLPNH120pp 0.0 Cardiolipin hydrolase (periplasm, n-C12:0)
# CLPNH140pp 0.0 Cardiolipin hydrolase (periplasm, n-C14:0)
# CLPNH141pp 0.0 Cardiolipin hydrolase (periplasm, n-C14:1)
# CLPNH160pp 0.0 Cardiolipin hydrolase (periplasm, n-C16:0)
# CLPNH161pp 0.0 Cardiolipin hydrolase (periplasm, n-C16:1)
# CLPNH180pp 0.0 Cardiolipin hydrolase (periplasm, n-C18:0)
# CLPNH181pp 0.0 Cardiolipin hydrolase (periplasm, n-C18:1)
# CLPNS120pp 0.0 Cardiolipin synthase (periplasmic, n-C12:0)
# CLPNS140pp 0.0 Cardiolipin synthase (periplasmic, n-C14:0)
# CLPNS141pp 0.0 Cardiolipin synthase (periplasmic, n-C14:1)
# CLPNS160pp 0.0 Cardiolipin synthase (periplasmic, n-C16:0)
# CLPNS161pp 0.0 Cardiolipin synthase (periplasmic, n-C16:1)
# CLPNS180pp 0.0 Cardiolipin synthase (periplasmic, n-C18:0)
# CLPNS181pp 0.0 Cardiolipin synthase (periplasmic, n-C18:1)
# CLt3_2pp 0.002556622642621968 Chloride transport out via proton antiport (2:1) (periplasm)
# CLtex 0.005113245285243936 Chloride (Cl-1) transport via diffusion (extracellular to periplasm)
# CMPN 0.0 CMP nucleosidase
# CMPtex 0.0 CMP transport via diffusion (extracellular to periplasm)
# CMtex 0.0 Chloramphenicol transport via diffusion (extracellular to periplasm)
# CMtpp 0.0 Chloramphenicol transport via TolC system
# CO2tex -19.67522263566326 CO2 transport via diffusion (extracellular to periplasm)
# CO2tpp -19.67522263566326 CO2 transporter via diffusion (periplasm)
# COBALT2abcpp 0.0 Cobalt (Co+2) ABC transporter (periplasm)
# COBALT2t3pp 0.0 Cobalt (Co+2) transport out via proton antiport (periplasm)
# COBALT2tex 2.4559295318174523e-05 Cobalt (Co+2) transport via diffusion (extracellular to periplasm)
# COBALT2tpp 2.4559295318174523e-05 Cobalt transport in via permease (no H+)
# COLIPAKpp 0.0 Lipid A core kinase (periplasm)
# COLIPAPabctex 0.0 Core oligosaccharide lipid A diphosphate transport via ABC system (periplasm to extracellular)
# COLIPAabcpp 0.0 Core oligosaccharide lipid A transport via ABC system (periplasm)
# COLIPAabctex 0.0 Core oligosaccharide lipid A transport via ABC system (periplasm to extracellular)
# CPGNR1 0.0 Coprogen(Fe(III)) reductase
# CPGNR2 0.0 Coprogen(Fe(III)) reductase
# CPGNR3 0.0 Coprogen(Fe(III)) reductase
# CPGNUtex 0.0 Coprogen unloaded secretion (extracellular)
# CPGNUtpp 0.0 Coprogen unloaded secretion
# CPGNabcpp 0.0 Coprogen transport via ABC system (periplasm)
# CPGNexs 0.0 Coprogen Fe-loading reaction (spontaneaous)
# CPGNtonex 0.0 Coprogen transport via ton system (extracellular)
# CPH4S 0.0 6-carboxy-5,6,7,8-tetrahydropterin synthase
# CPMPS 0.00023969872230538333 Cyclic pyranopterin monophosphate synthase
# CPPPGO 0.00021906891423811674 Coproporphyrinogen oxidase (O2 required)
# CPPPGO2 0.0 Oxygen Independent coproporphyrinogen-III oxidase
# CRNBTCT 0.0 Gamma-butyrobetainyl-CoA: carnitine CoA transferase
# CRNCAL2 0.0 Carnitine-CoA Ligase
# CRNCAR 0.0 Carnitine-CoA racemase
# CRNCBCT 0.0 Crotonobetainyl-CoA: carnitine CoA transferase
# ...
# RNDR4b 0.0 Ribonucleoside-diphosphate reductase (UDP) (glutaredoxin)
# RNTR1c2 0.025704740851814182 Ribonucleoside-triphosphate reductase (ATP) (flavodoxin)
# RNTR2c2 0.02654073926444484 Ribonucleoside-triphosphate reductase (GTP) (flavodoxin)
# RNTR3c2 0.02654073926444484 Ribonucleoside-triphosphate reductase (CTP) (flavodoxin)
# RNTR4c2 0.025704740851814182 Ribonucleoside-triphosphate reductase (UTP) (flavodoxin)
# RPE 1.9589431790865683 Ribulose 5-phosphate 3-epimerase
# RPI -2.083889346796208 Ribose-5-phosphate isomerase
# RZ5PP 0.0 Alpha-ribazole 5-phosphate phosphatase
# S2FE2SR 0.0 SUF [2Fe-2S] regeneration
# S2FE2SS 0.0 SUF [2Fe-2S] Synthesis
# S2FE2SS2 0.0 SUF [2Fe-2S] Synthesis II
# S2FE2ST 0.0 SUF [2Fe-2S] Transfer
# S4FE4SR 0.0 SUF [4Fe-4S] Reduction
# S4FE4ST 0.0 SUF [4Fe-4S] Transfer
# S7PI 0.0 Sedoheptulose 7-phosphate isomerase
# SADH 0.0 Succinylarginine dihydrolase
# SADT2 0.24350246596426278 Sulfate adenyltransferase
# SARCOX 0.0 Sarcosine oxidase
# SBTPD 0.0 Sorbitol-6-phosphate dehydrogenase
# SBTptspp 0.0 D-sorbitol transport via PEP:Pyr PTS (periplasm)
# SBTtex 0.0 D-sorbitol transport via diffusion (extracellular to periplasm)
# SCYSDS 0.0 SUF Cysteine desulfuration
# SDPDS 0.3644098415592608 Succinyl-diaminopimelate desuccinylase
# SDPTA -0.3644098415592608 Succinyldiaminopimelate transaminase
# SELCYSS 0.0 Selenocysteine synthase
# SELGTHR 0.0 Selenate glutathione reductase
# SELGTHR2 0.0 Selenate glutathione reductase II
# SELGTHR3 0.0 Selenate glutathione reductase III
# SELNPS 0.0 Selenophosphate synthase
# SELR 0.0 Selenate reductase
# SELtex 0.0 Selenate transport via diffusion (extracellular to periplasm)
# SELtpp 0.0 Selenate transport via proton symport (periplasm)
# SEPHCHCS 0.0 2-succinyl-5-enolpyruvyl-6-hydroxy-3-cyclohexene-1-carboxylate synthase
# SERASr 0.0 (L-seryl)adenylate synthase
# SERAT 0.24350246596426278 Serine O-acetyltransferase
# SERD_D 0.0 D-serine deaminase
# SERD_L 0.0 L-serine deaminase
# SERTRS 0.0 Seryl-tRNA synthetase
# SERTRS2 0.0 Seryl-tRNA synthetase (selenocystein)
# SERt2rpp 0.0 L-serine reversible transport via proton symport (periplasm)
# SERt4pp 0.0 L-serine via sodium symport (periplasm)
# SERtex 0.0 L-serine transport via diffusion (extracellular to periplasm)
# SFGTHi 0.0 S-Formylglutathione hydralase
# SGDS 0.0 Succinylglutamate desuccinylase
# SGSAD 0.0 Succinylglutamic semialdehyde dehydrogenase
# SHCHCS3 0.0 2-succinyl-6-hydroxy-2,4-cyclohexadiene 1-carboxylate synthase
# SHCHD2 0.00021906891423811674 Sirohydrochlorin dehydrogenase (NAD)
# SHCHF 0.00021906891423811674 Sirohydrochlorin ferrochelatase
# SHK3Dr 0.3744005628946941 Shikimate dehydrogenase
# SHKK 0.3744005628946941 Shikimate kinase
# SHSL1 0.15119782806862236 O-succinylhomoserine lyase (L-cysteine)
# SKMt2pp 0.0 Shikimate transport in via proton symport (periplasm)
# SKMtex 0.0 Shikimate transport via diffusion (extracellular to periplasm)
# SLNTtex 0.0 Selenite transport via diffusion (extracellular to periplasm)
# SLNTtpp 0.0 Selenite transport via proton symport (periplasm)
# SO2tex 0.0 SO2 transport via diffusion (extracellular to periplasm)
# SO2tpp 0.0 SO2 transport via diffusion (periplasm)
# SO3tex 0.0 Sulfite transport via diffusion (extracellular to periplasm)
# SO4t2pp 0.24776399488787243 Sulfate transport in via proton symport (periplasm to cytoplasm)
# SO4tex 0.24776399488787243 Sulfate transport via diffusion (extracellular to periplasm)
# SOTA 0.0 Succinylornithine transaminase
# SPMDAT1 0.0 Spermidine acetyltransferase
# SPMDAT2 0.0 Spermidine acetyltransferase (N8)
# SPMDabcpp 0.0 Spermidine transport via ABC system (periplasm)
# SPMDt3pp 0.0 Spermidine transport out via proton antiport (periplasm)
# SPMDtex 0.0 Spermidine transport via diffusion (extracellular to periplasm)
# SPMS 0.0 Spermidine synthase
# SPODM 0.0 Superoxide dismutase
# SPODMpp 0.0 Superoxide dismutase
# SSALx 0.0 Succinate-semialdehyde dehydrogenase (NAD)
# SSALy -1.326196097384269e-15 Succinate-semialdehyde dehydrogenase (NADP)
# SUCASPtpp 0.0 Succinate:aspartate antiporter (periplasm)
# SUCBZL 0.0 O-succinylbenzoate-CoA ligase
# SUCBZS 0.0 O-succinylbenzoate-CoA synthase
# SUCCt2_2pp 0.0 Succinate transport via proton symport (2 H) (periplasm)
# SUCCt2_3pp 0.0 Succintate transport via proton symport (3 H) (periplasm)
# SUCCt3pp 0.0 Succinate transport out via proton antiport (periplasm)
# SUCCtex 0.0 Succinate transport via diffusion (extracellular to periplasm)
# SUCDi 3.80219553689946 Succinate dehydrogenase (irreversible)
# SUCFUMtpp 0.0 Succinate:fumarate antiporter (periplasm)
# SUCMALtpp 0.0 Succinate:malate antiporter (periplasm)
# SUCOAS -3.285930660528864 Succinyl-CoA synthetase (ADP-forming)
# SUCRtex 0.0 Sucrose transport transport via diffusion (extracellular to periplasm)
# SUCTARTtpp 0.0 Succinate:D-tartrate antiporter (periplasm)
# SUCptspp 0.0 Sucrose transport via PEP:Pyr  (periplasm)
# SULFACabcpp 0.0 Sulfoacetate transport via ABC system (periplasm)
# SULFACtex 0.0 Sulfoaceate transport via diffusion (extracellular to periplasm)
# SULRi 0.24350246596426278 Sulfite reductase (NADPH2)
# SULabcpp 0.0 Sulfate transport via ABC system (periplasm)
# T2DECAI 0.0 Trans-2-decenoyl-ACP isomerase
# TAGURr 0.0 Tagaturonate reductase
# TALA 0.0 Transaldolase
# TARTD 0.0 L(+)-tartrate dehydratase
# TARTRDtex 0.0 D-tartrate transport via diffusion (extracellular to periplasm)
# TARTRt7pp 0.0 Tartrate/succinate antiporter (periplasm)
# TARTRtex 0.0 Tartrate transport via diffusion (extracellular to periplasm)
# TARTt2_3pp 0.0 D-tartrate transport via proton symport (3 H) (periplasm)
# TAUDO 0.0 Taurine dioxygenase
# TAURabcpp 0.0 Taurine transport via ABC system (periplasm)
# TAURtex 0.0 Taurine transport via diffusion (extracellular to periplasm)
# TCYNTtex 0.0 Thiocyanate transport via diffusion (extracellular to periplasm)
# TDP 0.0 Thiamin pyrophosphatase
# TDPADGAT 0.0 DTDP-4-amino-4,6-dideoxy-D-glucose acetyltransferase
# TDPAGTA 0.0 DTDP-4-amino-4,6-dideoxy-D-glucose transaminase
# TDPDRE 0.0 DTDP-4-dehydrorhamnose 3,5-epimerase
# TDPDRR 0.0 DTDP-4-dehydrorhamnose reductase
# TDPGDH 0.0 DTDPglucose 4,6-dehydratase
# TDSK 0.019113025988416143 Tetraacyldisaccharide 4'kinase
# TDSR1 0.0 Thiol:disulfide reductase (DsbC)
# TDSR2 0.0 Thiol:disulfide reductase (DsbG)
# TGBPA 0.0 Tagatose-bisphosphate aldolase
# THD2pp 0.0 NAD(P) transhydrogenase (periplasm)
# THDPS 0.3644098415592608 Tetrahydrodipicolinate succinylase
# THFAT 0.0 Tetrahydrofolate aminomethyltransferase
# THIORDXi 0.0 Hydrogen peroxide reductase (thioredoxin)
# THMDt2pp_copy1 0.0 None
# THMDt2pp_copy2 0.0 None
# THMDtex 0.0 Thymidine transport via diffusion (extracellular to periplasm)
# THMabcpp 0.0 Thiamine transport via ABC system (periplasm)
# THMtex 0.0 Thiamine transport via diffusion (extracellular to periplasm)
# THRA2i 0.0 L-allo-Threonine Aldolase
# THRAi 0.0 Threonine aldolase
# THRD 0.0 L-threonine dehydrogenase
# THRD_L 0.28540750037975704 L-threonine deaminase
# THRPtex 0.0 Phospho-L-threonine transport via diffusion (extracellular to periplasm)
# THRS 0.5346224584350266 Threonine synthase
# THRTRS 0.0 Threonyl-tRNA synthetase
# THRabcpp 0.0 L-threonine transport via ABC system (periplasm)
# THRt2pp 0.0 L-threonine efflux transport via proton antiport (periplasm)
# THRt2rpp 0.0 L-threonine reversible transport via proton symport (periplasm)
# THRt4pp 0.0 L-threonine  via sodium symport (periplasm)
# THRtex 0.0 L-threonine transport via diffusion (extracellular to periplasm)
# THYMt3pp 0.0 Thymine transport out via proton antiport (periplasm)
# THYMtex 0.0 Thymine transport via diffusion (extracellular to periplasm)
# THZPSN3 0.00021906891423811674 Thiazole phosphate synthesis
# TKT1 1.1667814054477503 Transketolase
# TKT2 0.7921617736388181 Transketolase
# TMAOR1 0.0 Trimethylamine N-oxide reductase (menaquinol 8)
# TMAOR1pp 0.0 Trimethylamine N-oxide reductase (menaquinol 8) (periplasm)
# TMAOR2 0.0 Trimethylamine N-oxide reductase (demethylmenaquinol 8)
# TMAOR2pp 0.0 Trimethylamine N-oxide reductase (demethylmenaquinol 8) (periplasm)
# TMAOtex 0.0 Trimethylamine N-oxide transport via diffusion (extracellular to periplasm)
# TMAtex 0.0 Trimethylamine transport via diffusion (extracellular to periplasm)
# TMDK1 0.0 Thymidine kinase (ATP:thymidine)
# TMDPP 0.0 Thymidine phosphorylase
# TMDS 0.025704740851814182 Thymidylate synthase
# TMK 0.0 Thiamine kinase
# TMPK 0.00021906891423811674 Thiamine-phosphate kinase
# TMPPP 0.00021906891423811674 Thiamine-phosphate diphosphorylase
# TPI 7.645370946359865 Triose-phosphate isomerase
# TPRDCOAS 0.0 Triphosphoribosyl-dephospho-CoA synthase
# TRDR 0.24350246596426278 Thioredoxin reductase (NADPH)
# TRE6PH 0.0 Trehalose-6-phosphate hydrolase
# TRE6PP 0.0 Trehalose-phosphatase
# TRE6PS 0.0 Alpha,alpha-trehalose-phosphate synthase (UDP-forming)
# TREH 0.0 Alpha,alpha-trehalase
# TREHpp 0.0 Alpha,alpha-trehalase (periplasm)
# TREptspp 0.0 Trehalose transport via PEP:Pyr PTS (periplasm)
# TREtex 0.0 Trehalose transport via diffusion (extracellular to periplasm)
# TRPAS2 -0.05584096095083978 Tryptophanase (L-tryptophan)
# TRPS1 0.0 Tryptophan synthase (indoleglycerol phosphate)
# TRPS2 0.0 Tryptophan synthase (indole)
# TRPS3 0.05584096095083978 Tryptophan synthase (indoleglycerol phosphate)
# TRPTRS 0.0 Tryptophanyl-tRNA synthetase
# TRPt2rpp 0.0 L-tryptophan reversible transport via proton symport (periplasm)
# TRPtex 0.0 L-tryptophan transport via diffusion (extracellular to periplasm)
# TRSARr 0.0 Tartronate semialdehyde reductase
# TSULabcpp 0.0 Thiosulfate transport via ABC system (periplasm)
# TSULtex 0.0 Thiosulfate transport via diffusion (extracellular to periplasm)
# TTDCAtexi 0.0 Tetradecanoate transport via facilitated irreversible diffusion (extracellular to periplasm)
# TTDCEAtexi 0.0 Tetradecenoate transport via facilitated irreversible diffusion (extracellular to periplasm)
# TTRCYCtex 0.0 Tetracycline transport via diffusion (extracellular to periplasm)
# TTRCYCtpp 0.0 Tetracycline transport via TolC system
# TUNGSabcpp 0.0 Tungstate transport via ABC system (periplasm)
# TUNGStex 0.0 Tungstate transport via diffusion (extracellular to periplasm)
# TYMtex 0.0 Tyramine transport via diffusion (extracellular to periplasm)
# TYRL 0.00021906891423811674 Tyrosine lyase
# TYROXDApp 0.0 Tyramine:oxygen oxidoreductase(deaminating)(flavin-containing) (periplasm)
# TYRPpp 0.0 Phospho-L-tyrosine phosphatase (periplasmic)
# TYRPtex 0.0 Phopho-L-tyrosine transport via diffusion (extracellular to periplasm)
# TYRTA -0.13568421240203787 Tyrosine transaminase
# TYRTRS 0.0 Tyrosyl-tRNA synthetase
# TYRt2rpp 0.0 L-tyrosine reversible transport via proton symport (periplasm)
# TYRtex 0.0 L-tyrosine transport via diffusion (extracellular to periplasm)
# ThDPAT 0.0 ThDP adenylyl transferase
# U23GAAT 0.038226051976832286 UDP-3-O-(3-hydroxymyristoyl)glucosamine acyltransferase
# UAAGDS 0.027298147932057346 UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimelate synthetase
# UACGALPpp 0.0 UDP-N-acetyl-D-galactosamine pyrophosphohydrolase (periplasm)
# UACGAMPpp 0.0 UDP-N-acetyl-D-glucosamine pyrophosphohydrolase (periplasm)
# UACGAMtex 0.0 UDP-N-acetyl-D-glucosamine transport via diffusion (extracellular to periplasm)
# UACMAMO 0.0 UDP-N-acetyl-D-mannosamine oxidoreductase
# UAG2E 0.0 UDP-N-acetylglucosamine 2-epimerase
# UAGAAT 0.038226051976832286 UDP-N-acetylglucosamine acyltransferase
# UAGCVT 0.027298147932057346 UDP-N-acetylglucosamine 1-carboxyvinyltransferase
# UAGDP 0.09282234784094698 UDP-N-acetylglucosamine diphosphorylase
# UAGPT3 0.027298147932057346 UDP-N-acetylglucosamine-N-acetylmuramyl-(pentapeptide)pyrophosphoryl-undecaprenol N-acetylglucosamine transferase
# UAMAGS 0.027298147932057346 UDP-N-acetylmuramoyl-L-alanyl-D-glutamate synthetase
# UAMAS 0.027298147932057346 UDP-N-acetylmuramoyl-L-alanine synthetase
# UAPGR 0.027298147932057346 UDP-N-acetylenolpyruvoylglucosamine reductase
# UDCPDP 0.027298147932057346 Undecaprenyl-diphosphatase
# UDCPDPS 5.403044969998345e-05 Undecaprenyl diphosphate synthase
# UDCPDPpp 0.0 Undecaprenyl-diphosphatase (periplasm)
# UDCPPtppi 0.0 Undecaprenyl phosphate transport (cytoplasm to periplasm)
# UDPACGALtex 0.0 UDP-N-acetyl-D-galactosamine transport via diffusion (extracellular to periplasm)
# UDPG4E 0.0 UDPglucose 4-epimerase
# UDPGALM 0.0 UDPgalactopyranose mutase
# UDPGALPpp 0.0 UDPgalactose pyrophosphohydrolase
# UDPGALtex 0.0 UDPgalactose transport via diffusion (extracellular to periplasm)
# UDPGD 0.0 UDPglucose 6-dehydrogenase
# UDPGDC 0.0 UDP-glucuronate C-4'' decarboxylase
# UDPGLCURtex 0.0 UDP-D-glucuronate transport via diffusion (extracellular to periplasm)
# UDPGPpp 0.0 UDPglucose pyrophosphohydrolase
# UDPGtex 0.0 UDPglucose transport via diffusion (extracellular to periplasm)
# UDPKAAT 0.0 UDP-4''-ketopentose:UDP-4-amino-4-deoxy-L-arabinose aminotransferase
# UGLCURPpp 0.0 UDP-D-glucuronate pyrophosphohydrolase (periplasm)
# UGLT 0.0 UDPglucose--hexose-1-phosphate uridylyltransferase
# UGLYCH 0.0 Ureidoglycolate hydrolase
# UGMDDS 0.027298147932057346 UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine synthetase
# UHGADA 0.038226051976832286 UDP-3-O-acetylglucosamine deacetylase
# ULA4NFT 0.0 UDP-L-Ara4N formyltransferase
# ULA4Ntppi 0.0 Transport (cytoplasm to periplasm)
# UM3PL 0.0 UDP-N-acetylmuramate:L-alanyl-gamma-D-glutamyl-meso-diaminopimelate ligase
# UM4PCP 0.0 UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate-D-alanine L,D-carboxypeptidase
# UM4PL 0.0 UDP-N-acetylmuramate:L-alanyl-gamma-D-glutamyl-meso-diaminopimelate-D-alanine ligase
# UMPK 0.3713748577114952 UMP kinase
# UMPtex 0.0 UMP transport via diffusion (extracellular to periplasm)
# UPLA4FNF 0.0 Undecaprenyl phosphate-L-Ara4FN formylase
# UPLA4FNT 0.0 Undecaprenyl phosphate-L-Ara4FN transferase
# UPP3MT 0.00021906891423811674 Uroporphyrinogen methyltransferase
# UPP3S 0.0004381378284762335 Uroporphyrinogen-III synthase
# UPPDC1 0.00021906891423811674 Uroporphyrinogen decarboxylase (uroporphyrinogen III)
# UPPRT 0.0 Uracil phosphoribosyltransferase
# URACPAH 0.0 Peroxyureidoacrylate hydrolase
# URAt2pp_copy1 0.0 None
# URAt2pp_copy2 0.0 None
# URAtex 0.0 Uracil transport via diffusion (extracellular to periplasm)
# URDGLYCD 0.0 Ureidoglycolate dehydrogenase
# UREAtex 0.0 Urea transport via diffusion (extracellular to periplasm)
# UREAtpp 0.0 Urea transport via facilitate diffusion (periplasm)
# URIC 0.0 Uricase
# URIH 0.0 Uridine hydrolase
# URIK2 0.0 Uridine kinase (GTP:Uridine)
# URIt2pp_copy1 0.0 None
# URIt2pp_copy2 0.0 None
# URItex 0.0 Uridine transport via diffusion (extracellular to periplasm)
# USHD 0.019113025988416143 UDP-sugar hydrolase
# VALTA 0.0 Valine transaminase
# VALTRS 0.0 Valyl-tRNA synthetase
# VALabcpp 0.0 L-valine transport via ABC system (periplasm)
# VALt2rpp 0.0 L-valine reversible transport via proton symport (periplasm)
# VALtex 0.0 L-valine transport via diffusion (extracellular to periplasm)
# VPAMTr 0.4157024210171747 Valine-pyruvate aminotransferase
# WCOS 0.0 Tungsten pterin cofactor synthase
# X5PL3E 0.0 L-xylulose 5-phosphate 3-epimerase
# XAND 0.0 Xanthine dehydrogenase
# XANt2pp 0.0 Xanthine transport in via proton symport (periplasm)
# XANtex 0.0 Xanthine transport via diffusion (extracellular to periplasm)
# XANtpp 0.0 Xanthine reversible transport (periplasm)
# XMPtex 0.0 XMP transport via diffusion (extracellular to periplasm)
# XPPT 0.0 Xanthine phosphoribosyltransferase
# XTSNH 0.0 Xanthosine hydrolase
# XTSNt2rpp 0.0 Xanthosine transport via proton symport (periplasm)
# XTSNtex 0.0 Xanthosine transport via diffusion (extracellular to periplasm)
# XYLI1 0.0 Xylose isomerase
# XYLI2 0.0 Xylose isomerase
# XYLK 0.0 Xylulokinase
# XYLK2 0.0 L-xylulokinase
# XYLUt2pp 0.0 L-xylulose transport in via proton symport (periplasm)
# XYLUtex 0.0 L-xylulose transport via diffusion (extracellular to periplasm)
# XYLabcpp 0.0 D-xylose transport via ABC system (periplasm)
# XYLt2pp 0.0 D-xylose transport in via proton symport (periplasm)
# XYLtex 0.0 D-xylose transport via diffusion (extracellular to periplasm)
# ZN2abcpp 0.0 Zinc (Zn+2) ABC transporter, efflux (periplasm)
# ZN2t3pp 0.0 Zinc (Zn+2) transport out via proton antiport (periplasm)
# ZN2tpp 0.0003349887881399005 Zinc transport in via permease (no H+)
# ZNabcpp 0.0 Zinc (Zn+2) transport via ABC system (periplasm)
# Zn2tex 0.0003349887881399005 Zinc (Zn+2) transport via diffusion (extracellular to periplasm)

# %% [markdown]
# The growth rate is 0.98 $h^{-1}$.

# %%
model.reactions.BIOMASS_Ec_iJO1366_core_53p95M.flux
# Out:
# 0.9823718127269809

# %%
solution_frame = solution.to_frame()
solution_frame[solution_frame.fluxes != 0.]
# Out:
#                                     fluxes  reduced_costs
# DM_4crsol_c                     2.1907e-04     0.0000e+00
# DM_5drib_c                      2.2103e-04     0.0000e+00
# DM_amob_c                       1.9647e-06     0.0000e+00
# DM_mththf_c                     4.4010e-04     0.0000e+00
# BIOMASS_Ec_iJO1366_core_53p95M  9.8237e-01    -1.3661e-15
# ...                                    ...            ...
# UPPDC1                          2.1907e-04     8.6736e-18
# USHD                            1.9113e-02    -3.2092e-17
# VPAMTr                          4.1570e-01     0.0000e+00
# ZN2tpp                          3.3499e-04     0.0000e+00
# Zn2tex                          3.3499e-04     0.0000e+00
#
# [440 rows x 2 columns]

# %%
solution_frame
# Out:
#                  fluxes  reduced_costs
# DM_4crsol_c  2.1907e-04         0.0000
# DM_5drib_c   2.2103e-04         0.0000
# DM_aacald_c  0.0000e+00         0.0000
# DM_amob_c    1.9647e-06         0.0000
# DM_mththf_c  4.4010e-04         0.0000
# ...                 ...            ...
# ZN2abcpp     0.0000e+00        -0.0083
# ZN2t3pp      0.0000e+00        -0.0021
# ZN2tpp       3.3499e-04         0.0000
# ZNabcpp      0.0000e+00        -0.0083
# Zn2tex       3.3499e-04         0.0000
#
# [2583 rows x 2 columns]

# %% [markdown]
# ## Exercise
#
# 1. Go to [bigg.ucsd.edu](http://bigg.ucsd.edu) and download a model in SBML format.
# 1. Load the model using `load_model`.
# 1. Optimize the flux distribution using regular flux balance analysis.
# 1. What is the objective value?
